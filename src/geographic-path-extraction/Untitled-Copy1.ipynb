# %%
import pandas as pd
import numpy as np
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import accuracy_score
from pathlib import Path
import os
import nltk

nltk.download('stopwords')

basepath = os.path.dirname(os.path.abspath('__file__'))
datapath1 = os.path.dirname(basepath)
datapath = os.path.dirname(datapath1)

np.random.seed(500)
# Out:
# [nltk_data] Downloading package stopwords to /home/ruta/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#datapath = Path(__file__).resolve().parents[2]

part = "part1"
readfile = datapath + '/results/hugh-murray/part1/processed/part1-annotated-special.csv'
data1 = pd.read_csv(readfile, sep='\t', encoding='latin1', error_bad_lines=False)

# %%
data = data1[data1.Location.notnull()].reset_index()

print("test")
data['sentence']= [word_tokenize(entry) for entry in data['sentence']]

# WordNetLemmatizer requires Pos tags to understand if the word is noun or verb or adjective etc. By default it is set to Noun
tag_map = defaultdict(lambda : wn.NOUN)
tag_map['J'] = wn.ADJ
tag_map['V'] = wn.VERB
tag_map['R'] = wn.ADV
for index,entry in enumerate(data['sentence']):
    print(type(entry))
    # Declaring Empty List to store the words that follow the rules for this step
    Final_words = []
    # Initializing WordNetLemmatizer()
    word_Lemmatized = WordNetLemmatizer()
    # pos_tag function below will provide the 'tag' i.e if the word is Noun(N) or Verb(V) or something else.
    for word, tag in pos_tag(entry):
        # Below condition is to check for Stop words and consider only alphabets
        if word not in stopwords.words('english') and word.isalpha():
            word_Final = word_Lemmatized.lemmatize(word,tag_map[tag[0]])
            Final_words.append(word_Final)
    # The final processed set of words for each iteration will be stored in 'text_final'
    #print(str(Final_words))
    data.loc[index,'sentence_final'] = str(Final_words)  

display(data)

    
print("Okay Done")
# Out:
# test
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
# <class 'list'>
#      index  chapterNo chapterTitle  sectionNo  SentenceNo  \
# 0        2          1       PART 1          1           3
# 1       48          1       PART 1          5          49
# 2       52          1       PART 1          6          53
# 3       56          1       PART 1          7          57
# 4      122          1       PART 1         10         123
# 5      149          1       PART 1         11         150
# 6      150          1       PART 1         11         151
# 7      160          1       PART 1         12         161
# 8      165          1       PART 1         12         166
# 9      192          1       PART 1         13         193
# 10     197          1       PART 1         13         198
# 11     216          1       PART 1         13         217
# 12     284          1       PART 1         19         285
# 13     289          1       PART 1         20         290
# 14     300          1       PART 1         22         301
# 15     314          1       PART 1         23         315
# 16     332          1       PART 1         23         333
# 17     333          1       PART 1         24         334
# 18     371          1       PART 1         25         372
# 19     382          1       PART 1         26         383
# 20     385          1       PART 1         26         386
# 21     400          1       PART 1         27         401
# 22     410          1       PART 1         28         411
# 23     437          1       PART 1         29         438
# 24     455          1       PART 1         30         456
# 25     457          1       PART 1         31         458
# 26     460          1       PART 1         31         461
# 27     463          1       PART 1         32         464
# 28     501          1       PART 1         34         502
# 29     503          1       PART 1         34         504
# ..     ...        ...          ...        ...         ...
# 167   1183          1       PART 1         76        1184
# 168   1184          1       PART 1         77        1185
# 169   1185          1       PART 1         77        1186
# 170   1188          1       PART 1         77        1189
# 171   1189          1       PART 1         77        1190
# 172   1192          1       PART 1         77        1193
# 173   1193          1       PART 1         77        1194
# 174   1196          1       PART 1         77        1197
# 175   1197          1       PART 1         77        1198
# 176   1199          1       PART 1         77        1200
# 177   1200          1       PART 1         77        1201
# 178   1201          1       PART 1         77        1202
# 179   1202          1       PART 1         78        1203
# 180   1203          1       PART 1         78        1204
# 181   1212          1       PART 1         79        1213
# 182   1221          1       PART 1         79        1222
# 183   1222          1       PART 1         79        1223
# 189  Of the most noble Port of Zai+AC0-tun, and of ...
# 190  Of the most noble Port of Zai+AC0-tun, and of ...
# 191  Of the most noble Port of Zai+AC0-tun, and of ...
# 192  Of the most noble Port of Zai+AC0-tun, and of ...
# 193  Of the most noble Port of Zai+AC0-tun, and of ...
# 194  Of the most noble Port of Zai+AC0-tun, and of ...
# 195  Of the most noble Port of Zai+AC0-tun, and of ...
# 196  Of the most noble Port of Zai+AC0-tun, and of ...
#
#                                     Marco Location  \
# 0                                          Kambalu
# 1                                          Kambalu
# 2                                          Kambalu
# 3                                          Kambalu
# 4                                          Kambalu
# 5                                          Kambalu
# 6                                          Kambalu
# 7                                          Kambalu
# 8                                          Kambalu
# 9                                          Kambalu
# 10                                         Kambalu
# 11                                         Kambalu
# 12                                         Kambalu
# 13                                         Kambalu
# 14                                         Kambalu
# 15                                         Kambalu
# 16                                         Kambalu
# 17                                         Kambalu
# 18                                         Kambalu
# 19                                         Kambalu
# 20                                         Kambalu
# 21                                         Kambalu
# 22                                         Kambalu
# 23                                         Kambalu
# 24                                         Kambalu
# 25                                         Kambalu
# 26                                         Kambalu
# 27                                         Kambalu
# 28                                     Pulisangan
# 29                                             NaN
# ..                                             ...
# 167                                            NaN
# 168  Tam-pin-gui,Un-gui,Chen-gui,Cian-cian,Can-gui
# 169                                            NaN
# 170                                            NaN
# 171                                            NaN
# 172                                            NaN
# 173                                            NaN
# 174                                            NaN
# 175                                            NaN
# 176                                            NaN
# 177                                            NaN
# 178                                            NaN
# 179                                         Fu-gui
# 180                                            NaN
# 181                                     Que-lin-fu
# 182                                            NaN
# 183                                            NaN
# 184                                         Fu-gui
# 185                                            NaN
# 186                                            NaN
# 187                                            NaN
# 188                             Zai-tun,Ti-min-gui
# 189                                            NaN
# 190                                            NaN
# 191                                            NaN
# 192                                            NaN
# 193                                            NaN
# 194                                            NaN
# 195                                            NaN
# 196                                            NaN
#
#                                               sentence  \
# 0    [Whosoever, descends, in, the, direct, line, f...
# 1    [These, were, Cicorcia, ,, Cauli, ,, Bastol, ,...
# 2    [Having, gained, this, victory, ,, the, great,...
# 3    [The, grand, khan, ,, having, obtained, this, ...
# 4    [He, resides, in, the, vast, city, of, Kambalu...
# 5    [Having, described, to, you, the, palaces, ,, ...
# 6    [Near, it, is, another, large, and, splendid, ...
# 7    [There, is, a, vast, abundance, of, people, th...
# 8    [There, are, brought, also, to, Kambalu, the, ...
# 9    [He, proposed, the, measure, to, one, of, his,...
# 10   [The, grand, khan, ,, having, acquired, the, s...
# 11   [When, his, majesty, returned, to, Kambalu, ,,...
# 12   [He, resides, in, the, city, of, Cathay, ,, th...
# 13   [He, has, also, many, lions, larger, than, tho...
# 14   [When, the, monarch, has, remained, in, Kambal...
# 15   [When, this, mighty, monarch, comes, to, one, ...
# 16   [The, great, khan, then, returns, to, the, cit...
# 17   [At, Shandu, in, Tartary, ,, near, the, wester...
# 18   [At, Cianganor, ,, too, ,, three, days, ', jou...
# 19   [With, regard, to, the, money, of, Kambalu, ,,...
# 20   [He, then, causes, them, to, be, cut, into, pi...
# 27                             Kambalu                    FALSE
# 28                             Kambalu                     TRUE
# 29                  Kambalu,Pulisangan                True,True
# ..                                 ...                      ...
# 167                Kin-sai,Tam-pin-gui                True,True
# 168                            Kin-sai                     TRUE
# 169                            Kin-sai                    FALSE
# 170                     Un-gui,Kin-sai               True,False
# 171                             Un-gui                     TRUE
# 172                           Chen-gui                     TRUE
# 173                            Kin-sai                    FALSE
# 174                              Manji                    FALSE
# 175                          Cian-cian                     TRUE
# 176                            Can-giu                     TRUE
# 177                            Kin-sai                    FALSE
# 178                       Manji,Fu-gui               False,True
# 179                      Kinsai,Fu-gui                True,True
# 180                             Fu-gui                     TRUE
# 181                         Que-lin-fu                     TRUE
# 182                            Un-quem                     TRUE
# 183                             Fu-gui                     TRUE
# 184               Fu-gui,Con-cha,Manji                True,True
# 185                              India                    FALSE
# 186                  Zai-tun,Hindostan                    FALSE
# 187                             Fu-gui                    FALSE
# 188                             Fu-gui                     TRUE
# 189                             Fu-gui                     TRUE
# 190     Zai-tun,Alexandria,Christendom         True,False,False
# 191                              India                    FALSE
# 192                         Ti-min-gui                     TRUE
# 193                             Fu-gui                    FALSE
# 194                            Kin-sai                    FALSE
# 195       Manji, Manji, Kin-sai,Fu-gui        False,False,False
# 196                              India                    FALSE
#
#                                         sentence_final
# 0    ['Whosoever', 'descend', 'direct', 'line', 'Ge...
# 1    ['These', 'Cicorcia', 'Cauli', 'Bastol', 'Such...
# 2    ['Having', 'gain', 'victory', 'great', 'khan',...
# 3    ['The', 'grand', 'khan', 'obtain', 'splendid',...
# 4    ['He', 'reside', 'vast', 'city', 'Kambalu', 't...
# 5    ['Having', 'describe', 'palace', 'I', 'tell', ...
# 6    ['Near', 'another', 'large', 'splendid', 'one'...
# 7    ['There', 'vast', 'abundance', 'people', 'subu...
# 8    ['There', 'bring', 'also', 'Kambalu', 'costly'...
# 9    ['He', 'propose', 'measure', 'one', 'nation', ...
# 10   ['The', 'grand', 'khan', 'acquire', 'sovereign...
# 11   ['When', 'majesty', 'return', 'Kambalu', 'inqu...
# 12   ['He', 'reside', 'city', 'Cathay', 'Kambalu', ...
# 13   ['He', 'also', 'many', 'lion', 'large', 'Babyl...
# 14   ['When', 'monarch', 'remain', 'Kambalu', 'thre...
# 15   ['When', 'mighty', 'monarch', 'come', 'one', '...
# 16   ['The', 'great', 'khan', 'return', 'city', 'Ka...
# 17   ['At', 'Shandu', 'Tartary', 'near', 'western',...
# 18   ['At', 'Cianganor', 'three', 'day', 'journey',...
# 19   ['With', 'regard', 'money', 'Kambalu', 'great'...
# 20   ['He', 'cause', 'cut', 'piece', 'declare', 'wo...
# 21   ['They', 'reside', 'palace', 'within', 'city',...
# 22   ['I', 'must', 'inform', 'city', 'Kambalu', 'ma...
# 23   ['bestow', 'also', 'great', 'charity', 'many',...
# 24   ['You', 'must', 'know', 'great', 'part', 'peop...
# 25   ['It', 'may', 'observe', 'also', 'throughout',...
# 26    ['Throughout', 'whole', 'Cathay', 'fuel', 'use']
# 27   ['The', 'city', 'Kambalu', 'contains', 'inclus...
# 28   ['I', 'inform', 'great', 'khan', 'send', 'Mess...
# 29   ['When', 'man', 'leave', 'Kambalu', 'go', 'ten...
# ..                                                 ...
# 167  ['Now', 'let', 'u', 'depart', 'city', 'go', 'a...
# 168  ['When', 'man', 'depart', 'go', 'day', 'find',...
# 169  ['At', 'end', 'day', 'discover', 'city', 'alre...
# 170  ['And', 'man', 'go', 'three', 'day', 'see', 'l...
# 171  ['When', 'depart', 'go', 'two', 'day', 'every'...
# 172  ['At', 'end', 'two', 'day', 'come', 'large', '...
# 173  ['The', 'people', 'idolater', 'great', 'khan',...
# 174  ['Throughout', 'province', 'Manji', 'neither',...
# 175  ['At', 'end', 'four', 'day', 'find', 'town', '...
# 176  ['end', 'three', 'day', 'reach', 'city', 'larg...
# 177                           ['last', 'jurisdiction']
# 178  ['commence', 'another', 'kingdom', 'one', 'nin...
# 179  ['When', 'man', 'go', 'city', 'Kinsai', 'enter...
# 180  ['travel', 'seven', 'day', 'find', 'house', 'v...
# 181  ['In', 'middle', 'seven', 'day', 'come', 'city...
# 182  ['At', 'end', 'journey', 'find', 'city', 'call...
# 183  ['Beyond', 'large', 'city', 'capital', 'kingdom']
# 184  ['state', 'capital', 'kingdom', 'one', 'nine',...
# 185  ['much', 'sugar', 'make', 'extensive', 'trade'...
# 186  ['It', 'also', 'near', 'port', 'ocean', 'whith...
# 187                       ['ascend', 'great', 'river']
# 188  ['When', 'one', 'depart', 'pass', 'river', 'go...
# 189  ['The', 'people', 'idolater', 'great', 'khan',...
# 190  ['At', 'end', 'five', 'day', 'find', 'city', '...
# 191  ['Know', 'khan', 'draw', 'thence', 'large', 'r...
# 192  ['In', 'province', 'city', 'name', 'make', 'be...
# 193                      ['The', 'people', 'language']
# 194  ['Now', 'I', 'tell', 'kingdom', 'one', 'nine',...
# 195  ['We', 'tell', 'nine', 'kingdom', 'Manji', 'th...
# 196  ['And', 'I', 'assure', 'Marco', 'remain', 'lon...
#
# [197 rows x 11 columns]
# Okay Done

# %%
Train_X, Test_X, Train_Y, Test_Y = model_selection.train_test_split(data['sentence_final'],data['Result'],test_size=0.3)

Encoder = LabelEncoder()
Train_Y = Encoder.fit_transform(Train_Y)
Test_Y = Encoder.fit_transform(Test_Y)

# %%
Tfidf_vect = TfidfVectorizer(max_features=5000)
Tfidf_vect.fit(data['sentence_final'])
Train_X_Tfidf = Tfidf_vect.transform(Train_X)
Test_X_Tfidf = Tfidf_vect.transform(Test_X)
print(type(Train_X_Tfidf))
print(Train_X_Tfidf.shape)
print(Train_Y.shape)
#print(Tfidf_vect.vocabulary_)
# Out:
# <class 'scipy.sparse.csr.csr_matrix'>
# (137, 690)
# (137,)

# %%
# fit the training dataset on the NB classifier
Naive = naive_bayes.MultinomialNB()
Naive.fit(Train_X_Tfidf,Train_Y)
# predict the labels on validation dataset
predictions_NB = Naive.predict(Test_X_Tfidf)
# Use accuracy_score function to get the accuracy
print("Naive Bayes Accuracy Score -> ",accuracy_score(predictions_NB, Test_Y)*100)
# Out:
# Naive Bayes Accuracy Score ->  65.0

# %%
# Classifier - Algorithm - SVM
# fit the training dataset on the classifier
SVM = svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto')
SVM.fit(Train_X_Tfidf,Train_Y)
# predict the labels on validation dataset
predictions_SVM = SVM.predict(Test_X_Tfidf)
# Use accuracy_score function to get the accuracy
print("SVM Accuracy Score -> ",accuracy_score(predictions_SVM, Test_Y)*100)
# Out:
# SVM Accuracy Score ->  66.66666666666666
