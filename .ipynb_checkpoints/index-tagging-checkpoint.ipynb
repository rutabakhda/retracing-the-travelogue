# %%
import os
import pandas as pd
import numpy as np


basepath = os.path.dirname(os.path.abspath('__file__'))
datapath = basepath + '/data/hugh-murray/index/'
readfile1 = 'index.csv'

df = pd.read_csv(datapath + readfile1,sep=',',encoding='ISO-8859-1',nrows=100)

df.head()
# Out:
#            Entity Name                                       Type      Page No
# 0  ABASCIA (Abyssinia)                                 kingdom of          324
# 1  ABASCIA (Abyssinia)      The inhibitants convertedby St Thomas          325
# 2  ABASCIA (Abyssinia)  Its king defated the ruler of Adel (Aden)          326
# 3  ABASCIA (Abyssinia)                 Productions of the country          327
# 4  ABASCIA (Abyssinia)             Abraiamain (Bramins), order of  293,304-308

# %%
from nltk.tag import StanfordNERTagger
from nltk.tokenize import word_tokenize
from nltk.tag import StanfordPOSTagger
import re

stanford_dir = "E:\python\standford-nlp\stanford-postagger-2018-10-16"
modelfile = stanford_dir+"\models\english-bidirectional-distsim.tagger"
jarfile=stanford_dir+"\stanford-postagger.jar"

def remove_special_characters(text):
    pattern = r'[^a-zA-z\s]'
    text = re.sub(pattern, '', text)
    return text

new_data = pd.DataFrame(columns=['Entity Name', 'Type', 'Page No','word','tag'])
for index,row in df.iterrows():
    if row[1]:
        text = remove_special_characters(row[1])
        print(text)
        new_row = {}
        new_row['Entity Name'] = row[0]
        new_row['Type'] = row[1]
        new_row['Page No'] = row[2]

        tagger=StanfordPOSTagger(model_filename=modelfile, path_to_jar=jarfile)
        tagged_text = tagger.tag(text.split())

        st = StanfordNERTagger('data/standford-nlp/stanford-ner-2014-06-16/classifiers/english.all.3class.distsim.crf.ser.gz', 'data/standford-nlp/stanford-ner-2014-06-16/stanford-ner.jar', encoding='utf-8')
        classified_text = st.tag(text.split())

        mylist = []
        for word,tag in tagged_text:
            if tag.startswith('VB') or tag.startswith('IN'):
                break
            else:

                mylist.append([word,tag])

        print(mylist)

        for word,tag in mylist:
            if tag.startswith('N'):
                final_noun_word = word

        print(final_noun_word)

        for word,tag in classified_text:
            if word == final_noun_word:
                if tag == 'O':
                    final_tag = 'PEOPLE'
                    print(final_tag)
                    break


        new_row['word'] = word
        new_row['tag'] = tag
        new_data.loc[len(new_data)] = new_row

new_data.to_csv(datapath + "index-processed.csv",sep=',',encoding='ISO-8859-1',index=False)


df.head()
# Out:
# kingdom of
# [['kingdom', 'NN']]
# kingdom
# PEOPLE
# The inhibitants convertedby St Thomas
# [['The', 'DT'], ['inhibitants', 'NNS']]
# inhibitants
# PEOPLE
# Its king defated the ruler of Adel Aden
# [['Its', 'PRP$'], ['king', 'NN']]
# king
# PEOPLE
# Productions of the country
# [['Productions', 'NNP']]
# Productions
# PEOPLE
# Abraiamain Bramins order of
# [['Abraiamain', 'FW'], ['Bramins', 'FW'], ['order', 'NN']]
# order
# PEOPLE
# province of
# [['province', 'NN']]
# province
# PEOPLE
# chief minister of Kublaihis wicked administration
# [['chief', 'JJ'], ['minister', 'NN']]
# minister
# PEOPLE
# Is slain by Vanku and Chenku
# []
# minister
# the Saracen contends for the Persian empire
# [['the', 'DT'], ['Saracen', 'NNP']]
# Saracen
# His batpers Argon
# [['His', 'PRP$'], ['batpers', 'NNS'], ['Argon', 'NNP']]
# Argon
# PEOPLE
# Is seized and slain
# []
# Argon
# a city of Palestine
# [['a', 'DT'], ['city', 'NN']]
# city
# PEOPLE
# a mountain of Ceylon
# [['a', 'DT'], ['mountain', 'NN']]
# mountain
# PEOPLE
# a kingdom and city of Eastern Africa
# [['a', 'DT'], ['kingdom', 'NN'], ['and', 'CC'], ['city', 'NN']]
# city
# PEOPLE
# Is invaded by the King of Absscia
# []
# city
# a city and and kingdom of Arabia
# [['a', 'DT'], ['city', 'NN'], ['and', 'CC'], ['and', 'CC'], ['kingdom', 'NN']]
# kingdom
# PEOPLE
# Inhabitated by Sarcensib
# []
# kingdom
# A great seat of Indian commerce ib
# [['A', 'DT'], ['great', 'JJ'], ['seat', 'NN']]
# seat
# PEOPLE
# Its sultan assists Saladin in the siege of Acre
# [['Its', 'PRP$'], ['sultan', 'NN']]
# sultan
# PEOPLE
# the old Man of the Mountain
# [['the', 'DT'], ['old', 'JJ'], ['Man', 'NN']]
# Man
# PEOPLE
# His garden and castle
# [['His', 'PRP$'], ['garden', 'NN'], ['and', 'CC'], ['castle', 'NN']]
# castle
# PEOPLE
# How he trained andemployed his assassins
# [['How', 'WRB'], ['he', 'PRP']]
# castle
# His death
# [['His', 'PRP$'], ['death', 'NN']]
# death
# PEOPLE
# or Hoolaku ruler of Eastern Tartar sends ambassadors to the great khan Mangou
# [['or', 'CC'], ['Hoolaku', 'NNP'], ['ruler', 'NN']]
# ruler
# PEOPLE
# Makes war with Barka whom he defeats
# []
# ruler
# Captures Bagdad and subverts the caliphate
# []
# ruler
# Takes and puts to death the Old Man of the Mountain
# []
# ruler
# Is succeeded by Abaga
# []
# ruler
# where Gengis and his descendants are interred
# [['where', 'WRB'], ['Gengis', 'NNP'], ['and', 'CC'], ['his', 'PRP$'], ['descendants', 'NNS']]
# descendants
# PEOPLE
# province of
# [['province', 'NN']]
# province
# PEOPLE
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-f8491f226533> in <module>
#      16 for index,row in df.iterrows():
#      17     if row[1] != "":
# ---> 18         text = remove_special_characters(row[1])
#      19         print(text)
#      20         new_row = {}
#
# <ipython-input-4-f8491f226533> in remove_special_characters(text)
#      10 def remove_special_characters(text):
#      11     pattern = r'[^a-zA-z\s]'
# ---> 12     text = re.sub(pattern, '', text)
#      13     return text
#      14
#
# c:\users\lenovo\appdata\local\programs\python\python37-32\lib\re.py in sub(pattern, repl, string, count, flags)
#     190     a callable, it's passed the Match object and must return
#     191     a replacement string to be used."""
# --> 192     return _compile(pattern, flags).sub(repl, string, count)
#     193
#     194 def subn(pattern, repl, string, count=0, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
readfile2 = 'index-processed.csv'

df2 = pd.read_csv(datapath + readfile2,sep=',',encoding='ISO-8859-1')

df2.head()
